# %%
from data_cleaning import DataCleaning
from data_extraction import DataExtractor
from database_utils import DatabaseConnector
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
stores_df = DataExtractor.retrieve_stores_data()
# Out:
# Error retrieving data for store number 451: 500

# %%
stores_df
# Out:
#      index                                            address   longitude  \
# 0        1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...    51.62907
# 1        2        Heckerstraße 4/5\n50491 Säckingen, Landshut    48.52961
# 2        3  5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury       51.26
# 3        4  Studio 6\nStephen landing\nSouth Simon\nB77 2W...     53.0233
# 4        5  Flat 92u\nChristian harbors\nPort Charlotte\nN...    53.38333
# ..     ...                                                ...         ...
# 445    446    Täschestraße 25\n39039 Nördlingen, Kirchlengern        52.2
# 446    447                                         K0ODETRLS3  K8CXLZDP07
# 447    448  Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High...    51.62907
# 448    449               Baumplatz 6\n80114 Kötzting, Bretten    49.03685
# 449    450  Gotthilf-Rose-Straße 7/3\n45457 Feuchtwangen, ...    50.64336
#
#             lat      locality   store_code staff_numbers opening_date  \
# ...

# %%
cleaned_store = DataCleaning.called_clean_store_data(stores_df)

# %%
DatabaseConnector.upload_to_db(cleaned_store, 'dim_store_details')
# Out:
# Data uploaded to table dim_store_details

# %%
products_df = DataExtractor.extract_from_s3()

# %%
products_df
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
# ...
